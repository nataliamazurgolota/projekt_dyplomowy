# %% [markdown]
# #### Import of pandas library and uploading dataset from csv file

# %%
import pandas as pd

# %%
raw_data = pd.read_csv("/home/student/Pulpit/nypd.csv", low_memory=False)

# %% [markdown]
# #### Getting information about columns which this dataset contains

# %%
raw_data.info()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612178 entries, 0 to 1612177
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   ACCIDENT DATE                  1612178 non-null  object
#  1   ACCIDENT TIME                  1612178 non-null  object
#  2   BOROUGH                        1127553 non-null  object
#  3   ZIP CODE                       1127376 non-null  object
#  4   LATITUDE                       1415893 non-null  float64
#  5   LONGITUDE                      1415893 non-null  float64
#  6   LOCATION                       1415893 non-null  object
#  7   ON STREET NAME                 1298002 non-null  object
#  8   CROSS STREET NAME              1079193 non-null  object
# ...

# %% [markdown]
# #### First and last ten rows of the dataset - for showing what the dataset looks like

# %%
raw_data.head(10)
# Out:
#              ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE   LATITUDE  \
# 0  2019-08-05T00:00:00.000         16:30     QUEENS    11434  40.676052
# 1  2019-08-27T00:00:00.000         16:02   BROOKLYN    11225  40.657780
# 2  2019-08-15T00:00:00.000         17:57  MANHATTAN    10002  40.718143
# 3  2019-08-30T00:00:00.000         21:53      BRONX    10460  40.840534
# 4  2019-08-06T00:00:00.000          9:45  MANHATTAN    10016  40.745440
# 5  2019-08-29T00:00:00.000         12:28   BROOKLYN    11222  40.726524
# 6  2019-08-31T00:00:00.000          2:16     QUEENS    11434  40.667522
# 7  2019-08-11T00:00:00.000         22:23        NaN      NaN  40.858210
# 8  2019-08-02T00:00:00.000         16:30     QUEENS    11434  40.666492
# 9  2019-08-21T00:00:00.000         17:30      BRONX    10452  40.837720
#
#    LONGITUDE                                           LOCATION  \
# 0 -73.790184  {'type': 'Point', 'coordinates': [-73.790184, ...
# ...

# %%
raw_data.tail(10)
# Out:
#                    ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE   LATITUDE  \
# 1612168  2012-07-07T00:00:00.000         12:48  MANHATTAN    10002  40.723425
# 1612169  2012-07-05T00:00:00.000         12:50   BROOKLYN    11217  40.686930
# 1612170  2012-07-16T00:00:00.000         16:00   BROOKLYN    11211  40.712491
# 1612171  2012-07-14T00:00:00.000         18:30   BROOKLYN    11216  40.680089
# 1612172  2012-07-08T00:00:00.000         22:30     QUEENS    11368  40.742096
# 1612173  2012-07-21T00:00:00.000         22:46   BROOKLYN    11226  40.651741
# 1612174  2012-07-09T00:00:00.000         16:45        NaN      NaN        NaN
# 1612175  2012-07-09T00:00:00.000         14:35        NaN      NaN  40.791492
# 1612176  2012-07-18T00:00:00.000          9:20  MANHATTAN    10024  40.779479
# 1612177  2012-07-12T00:00:00.000          3:10     QUEENS    11361  40.762501
#
#          LONGITUDE                                           LOCATION  \
# ...

# %% [markdown]
# ### Conclusions:
# #### The dataset contains information about accidents reported in New York City from 2012 to 2019.
# #### The dataset contains 29 columns and around 1600000 rows.
