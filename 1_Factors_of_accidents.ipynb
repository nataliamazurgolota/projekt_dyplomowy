# %%
import pandas as pd

# %%
df = pd.read_csv("/home/student/Pulpit/nypd.csv", low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612178 entries, 0 to 1612177
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   ACCIDENT DATE                  1612178 non-null  object
#  1   ACCIDENT TIME                  1612178 non-null  object
#  2   BOROUGH                        1127553 non-null  object
#  3   ZIP CODE                       1127376 non-null  object
#  4   LATITUDE                       1415893 non-null  float64
#  5   LONGITUDE                      1415893 non-null  float64
#  6   LOCATION                       1415893 non-null  object
#  7   ON STREET NAME                 1298002 non-null  object
#  8   CROSS STREET NAME              1079193 non-null  object
#  9   OFF STREET NAME                219732 non-null   object
#  10  NUMBER OF PERSONS INJURED      1612161 non-null  float64
# ...

# %%
df.head()
# Out:
#              ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE   LATITUDE  \
# 0  2019-08-05T00:00:00.000         16:30     QUEENS    11434  40.676052
# 1  2019-08-27T00:00:00.000         16:02   BROOKLYN    11225  40.657780
# 2  2019-08-15T00:00:00.000         17:57  MANHATTAN    10002  40.718143
# 3  2019-08-30T00:00:00.000         21:53      BRONX    10460  40.840534
# 4  2019-08-06T00:00:00.000          9:45  MANHATTAN    10016  40.745440
#
#    LONGITUDE                                           LOCATION  \
# 0 -73.790184  {'type': 'Point', 'coordinates': [-73.790184, ...
# 1 -73.951096  {'type': 'Point', 'coordinates': [-73.951096, ...
# 2 -73.993835  {'type': 'Point', 'coordinates': [-73.993835, ...
# 3 -73.866610  {'type': 'Point', 'coordinates': [-73.86661, 4...
# 4 -73.975400  {'type': 'Point', 'coordinates': [-73.9754, 40...
#
#                      ON STREET NAME CROSS STREET NAME  \
# 0                               NaN               NaN
# ...

# %%
df.isnull().sum()
# Out:
# ACCIDENT DATE                          0
# ACCIDENT TIME                          0
# BOROUGH                           484625
# ZIP CODE                          484802
# LATITUDE                          196285
# LONGITUDE                         196285
# LOCATION                          196285
# ON STREET NAME                    314176
# CROSS STREET NAME                 532985
# OFF STREET NAME                  1392446
# NUMBER OF PERSONS INJURED             17
# NUMBER OF PERSONS KILLED              33
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       4324
# CONTRIBUTING FACTOR VEHICLE 2     216051
# CONTRIBUTING FACTOR VEHICLE 3    1507924
# CONTRIBUTING FACTOR VEHICLE 4    1590389
# CONTRIBUTING FACTOR VEHICLE 5    1606556
# ...

# %%
data = df.drop(["ON STREET NAME","CROSS STREET NAME","OFF STREET NAME","LATITUDE","LONGITUDE","CONTRIBUTING FACTOR VEHICLE 4","VEHICLE TYPE CODE 4","CONTRIBUTING FACTOR VEHICLE 5","VEHICLE TYPE CODE 5"], axis=1)

# %%
data["CONTRIBUTING FACTOR VEHICLE 1"].value_counts()
# Out:
# CONTRIBUTING FACTOR VEHICLE 1
# Unspecified                       595805
# Driver Inattention/Distraction    299425
# Failure to Yield Right-of-Way      91617
# Following Too Closely              78467
# Backing Unsafely                   61445
#                                    ...
# Windshield Inadequate                 73
# Shoulders Defective/Improper          63
# Texting                               32
# Listening/Using Headphones            18
# 1                                     10
# Name: count, Length: 61, dtype: int64

# %%
data["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(30)
# Out:
# CONTRIBUTING FACTOR VEHICLE 1
# Unspecified                                              595805
# Driver Inattention/Distraction                           299425
# Failure to Yield Right-of-Way                             91617
# Following Too Closely                                     78467
# Backing Unsafely                                          61445
# Other Vehicular                                           51200
# Fatigued/Drowsy                                           48593
# Turning Improperly                                        41448
# Passing or Lane Usage Improper                            37398
# Passing Too Closely                                       34194
# Unsafe Lane Changing                                      30110
# Traffic Control Disregarded                               24495
# Driver Inexperience                                       23468
# Lost Consciousness                                        20064
# ...

# %%
accident_factor = data["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(20)

# %%
accident_factor.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 20 entries, Unspecified to Outside Car Distraction
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 20 non-null     int64
# dtypes: int64(1)
# memory usage: 320.0+ bytes

# %%
accident_factor.plot.bar()
# Out:
# <Axes: xlabel='CONTRIBUTING FACTOR VEHICLE 1'>

# %%
data_manhattan = data.loc[data['BOROUGH'] == "MANHATTAN"]

# %%
accident_factor_manhattan = data_manhattan["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(20)

# %%
accident_factor_manhattan.plot.bar()
# Out:
# <Axes: xlabel='CONTRIBUTING FACTOR VEHICLE 1'>

# %%
data_bronx = data.loc[data['BOROUGH'] == "BRONX"]

# %%
accident_factor_bronx = data_bronx["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(20)

# %%
accident_factor_bronx.plot.bar()
# Out:
# <Axes: xlabel='CONTRIBUTING FACTOR VEHICLE 1'>

# %%
data_queens = data.loc[data['BOROUGH'] == "QUEENS"]

# %%
accident_factor_queens = data_queens["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(20)

# %%
accident_factor_queens.plot.bar()
# Out:
# <Axes: xlabel='CONTRIBUTING FACTOR VEHICLE 1'>

# %%
data_brooklyn = data.loc[data['BOROUGH'] == "BROOKLYN"]

# %%
accident_factor_brooklyn = data_brooklyn["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(20)

# %%
accident_factor_brooklyn.plot.bar()
# Out:
# <Axes: xlabel='CONTRIBUTING FACTOR VEHICLE 1'>

# %%
data_staten_island = data.loc[data['BOROUGH'] == "STATEN ISLAND"]

# %%
accident_factor_staten_island = data_staten_island["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(20)

# %%
accident_factor_staten_island.plot.bar()
# Out:
# <Axes: xlabel='CONTRIBUTING FACTOR VEHICLE 1'>

# %%
accident_factor_staten_island2 = data_staten_island["CONTRIBUTING FACTOR VEHICLE 2"].value_counts().head(20)

# %%
accident_factor_staten_island2.plot.bar()
# Out:
# <Axes: xlabel='CONTRIBUTING FACTOR VEHICLE 2'>
